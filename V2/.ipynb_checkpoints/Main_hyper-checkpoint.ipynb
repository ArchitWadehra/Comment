# %% [markdown]
# ### Check conda environment

# %%
# Check Environment
import os
print(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# BTP2

# %%
# Check Python version
import sys
print(sys.version)
# Out:
# 3.9.15 | packaged by conda-forge | (main, Nov 22 2022, 08:39:05) [MSC v.1929 64 bit (AMD64)]

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.21.0

# %%
# Check Tensorflow version
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %%
# Open Gym Environment
import gym
import gym_mppt

# Check Gym Environments
from gym import envs
all_envs = envs.registry
for key, value in sorted(all_envs.items(), key=lambda x: x[0]): 
    print(key)
    
env = gym.make('mppt-v2')
# Out:
# Acrobot-v1
# Ant-v2
# Ant-v3
# Ant-v4
# BipedalWalker-v3
# BipedalWalkerHardcore-v3
# Blackjack-v1
# CarRacing-v2
# CartPole-v0
# CartPole-v1
# CliffWalking-v0
# FrozenLake-v1
# FrozenLake8x8-v1
# HalfCheetah-v2
# HalfCheetah-v3
# HalfCheetah-v4
# Hopper-v2
# Hopper-v3
# Hopper-v4
# Humanoid-v2
# Humanoid-v3
# Humanoid-v4
# HumanoidStandup-v2
# HumanoidStandup-v4
# InvertedDoublePendulum-v2
# InvertedDoublePendulum-v4
# InvertedPendulum-v2
# InvertedPendulum-v4
# LunarLander-v2
# LunarLanderContinuous-v2
# MountainCar-v0
# MountainCarContinuous-v0
# Pendulum-v1
# Pusher-v2
# Pusher-v4
# Reacher-v2
# Reacher-v4
# Swimmer-v2
# Swimmer-v3
# Swimmer-v4
# Taxi-v3
# Walker2d-v2
# Walker2d-v3
# Walker2d-v4
# mppt-v0
# mppt-v1
# mppt-v2
# mppt_shaded-v0
# mppt_shaded-v1

# %% [markdown]
# ### Tensorflow 2 Implementation

# %%
import gym
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %%
problem = "mppt-v2"
env = gym.make(problem)

num_states = env.observation_space.shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.shape[0]
print("Size of Action Space ->  {}".format(num_actions))

upper_bound = env.action_space.high[0]
lower_bound = env.action_space.low[0]

print("Max Value of Action ->  {}".format(upper_bound))
print("Min Value of Action ->  {}".format(lower_bound))
# Out:
# Size of State Space ->  3
# Size of Action Space ->  1
# Max Value of Action ->  15.0
# Min Value of Action ->  -15.0

# %%
class OUActionNoise:
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None):
        self.theta = theta
        self.mean = mean
        self.std_dev = std_deviation
        self.dt = dt
        self.x_initial = x_initial
        self.reset()

    def __call__(self):
        # Formula taken from https://www.wikipedia.org/wiki/Ornstein-Uhlenbeck_process.
        x = (
            self.x_prev
            + self.theta * (self.mean - self.x_prev) * self.dt
            + self.std_dev * np.sqrt(self.dt) * np.random.normal(size=self.mean.shape)
        )
        # Store x into x_prev
        # Makes next noise dependent on current one
        self.x_prev = x
        return x

    def reset(self):
        if self.x_initial is not None:
            self.x_prev = self.x_initial
        else:
            self.x_prev = np.zeros_like(self.mean)

# %%
class Buffer:
    def __init__(self, buffer_capacity=100000, batch_size=64):
        # Number of "experiences" to store at max
        self.buffer_capacity = buffer_capacity
        # Num of tuples to train on.
        self.batch_size = batch_size

        # Its tells us num of times record() was called.
        self.buffer_counter = 0

        # Instead of list of tuples as the exp.replay concept go
        # We use different np.arrays for each tuple element
        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, num_actions))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))

    # Takes (s,a,r,s') obervation tuple as input
    def record(self, obs_tuple):
        # Set index to zero if buffer_capacity is exceeded,
        # replacing old records
        index = self.buffer_counter % self.buffer_capacity

        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]

        self.buffer_counter += 1

    # Eager execution is turned on by default in TensorFlow 2. Decorating with tf.function allows
    # TensorFlow to build a static graph out of the logic and computations in our function.
    # This provides a large speed up for blocks of code that contain many small TensorFlow operations such as this one.
    @tf.function
    def update(
        self, state_batch, action_batch, reward_batch, next_state_batch,
    ):
        # Training and updating Actor & Critic networks.
        # See Pseudo Code.
        with tf.GradientTape() as tape:
            target_actions = target_actor(next_state_batch, training=True)
            y = reward_batch + gamma * target_critic(
                [next_state_batch, target_actions], training=True
            )
            critic_value = critic_model([state_batch, action_batch], training=True)
            critic_loss = tf.math.reduce_mean(tf.math.square(y - critic_value))

        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables)
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )

        with tf.GradientTape() as tape:
            actions = actor_model(state_batch, training=True)
            critic_value = critic_model([state_batch, actions], training=True)
            # Used `-value` as we want to maximize the value given
            # by the critic for our actions
            actor_loss = -tf.math.reduce_mean(critic_value)

        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables)
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

    # We compute the loss and update parameters
    def learn(self):
        # Get sampling range
        record_range = min(self.buffer_counter, self.buffer_capacity)
        # Randomly sample indices
        batch_indices = np.random.choice(record_range, self.batch_size)

        # Convert to tensors
        state_batch = tf.convert_to_tensor(self.state_buffer[batch_indices])
        action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
        reward_batch = tf.cast(reward_batch, dtype=tf.float32)
        next_state_batch = tf.convert_to_tensor(self.next_state_buffer[batch_indices])

        self.update(state_batch, action_batch, reward_batch, next_state_batch)


# This update target parameters slowly
# Based on rate `tau`, which is much less than one.
@tf.function
def update_target(target_weights, weights, tau):
    for (a, b) in zip(target_weights, weights):
        a.assign(b * tau + a * (1 - tau))

# %%
def get_actor():
    # Initialize weights between -3e-3 and 3-e3
    last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)

    inputs = layers.Input(shape=(num_states,))
    out = layers.Dense(256, activation="relu")(inputs)
    out = layers.Dense(256, activation="relu")(out)
    outputs = layers.Dense(1, activation="tanh", kernel_initializer=last_init)(out)

    # Our upper bound is 2.0 for Pendulum.
    outputs = outputs * upper_bound
    model = tf.keras.Model(inputs, outputs)
    return model


def get_critic():
    # State as input
    state_input = layers.Input(shape=(num_states))
    state_out = layers.Dense(16, activation="relu")(state_input)
    state_out = layers.Dense(32, activation="relu")(state_out)

    # Action as input
    action_input = layers.Input(shape=(num_actions))
    action_out = layers.Dense(32, activation="relu")(action_input)

    # Both are passed through seperate layer before concatenating
    concat = layers.Concatenate()([state_out, action_out])

    out = layers.Dense(256, activation="relu")(concat)
    out = layers.Dense(256, activation="relu")(out)
    outputs = layers.Dense(1)(out)

    # Outputs single value for give state-action
    model = tf.keras.Model([state_input, action_input], outputs)

    return model

# %%
def policy(state, noise_object):
    sampled_actions = tf.squeeze(actor_model(state))
    noise = noise_object()
    # Adding noise to action
    sampled_actions = sampled_actions.numpy() + noise

    # We make sure action is within bounds
    legal_action = np.clip(sampled_actions, lower_bound, upper_bound)

    return [np.squeeze(legal_action)]

# %%
std_dev = 0.2
ou_noise = OUActionNoise(mean=np.zeros(1), std_deviation=float(std_dev) * np.ones(1))

actor_model = get_actor()
critic_model = get_critic()

target_actor = get_actor()
target_critic = get_critic()

# Making the weights equal initially
target_actor.set_weights(actor_model.get_weights())
target_critic.set_weights(critic_model.get_weights())

# Learning rate for actor-critic models
critic_lr = 0.002
actor_lr = 0.001

critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

total_episodes = 100       # was 100
# Discount factor for future rewards
gamma = 0.99
# Used to update target networks
tau = 0.005

buffer = Buffer(50000, 64)

# %%
import warnings
warnings.filterwarnings('ignore')

# To store reward history of each episode
ep_reward_list = []
# To store average reward history of last few episodes
avg_reward_list = []

# Takes about 4 min to train
for ep in range(total_episodes):

    prev_state = env.reset()
    episodic_reward = 0

    while True:
        # Uncomment this to see the Actor in action
        # But not in a python notebook.
        # env.render()

        tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)

        action = policy(tf_prev_state, ou_noise)
        # Recieve state and reward from environment.
        state, reward, done, info = env.step(action)

        buffer.record((prev_state, action, reward, state))
        episodic_reward += reward

        buffer.learn()
        update_target(target_actor.variables, actor_model.variables, tau)
        update_target(target_critic.variables, critic_model.variables, tau)

        # End this episode when `done` is True
        if done:
            break

        prev_state = state

    ep_reward_list.append(episodic_reward)

    # Mean of last 40 episodes
    avg_reward = np.mean(ep_reward_list[-40:])
    print("Episode * {} * Avg Reward is ==> {}".format(ep, avg_reward))
    avg_reward_list.append(avg_reward)

# Plotting graph
# Episodes versus Avg. Rewards
plt.plot(avg_reward_list)
plt.xlabel("Episode")
plt.ylabel("Avg. Epsiodic Reward")
plt.show()
# Out:
# Episode * 0 * Avg Reward is ==> -101.99997738198928
# Episode * 1 * Avg Reward is ==> [-100.99998869]
# Episode * 2 * Avg Reward is ==> [-92.81514369]
# Episode * 3 * Avg Reward is ==> [-37.59336654]
# Episode * 4 * Avg Reward is ==> [-30.26881495]
# Episode * 5 * Avg Reward is ==> [-25.38602422]
# Episode * 6 * Avg Reward is ==> [-21.89812697]
# Episode * 7 * Avg Reward is ==> [-19.28242427]
# Episode * 8 * Avg Reward is ==> [-17.24807732]
# Episode * 9 * Avg Reward is ==> [-15.62071914]
# Episode * 10 * Avg Reward is ==> [-14.28941942]
# Episode * 11 * Avg Reward is ==> [-13.18008365]
# Episode * 12 * Avg Reward is ==> [-12.24154633]
# Episode * 13 * Avg Reward is ==> [-11.43713345]
# Episode * 14 * Avg Reward is ==> [-10.73989792]
# Episode * 15 * Avg Reward is ==> [-10.12973947]
# Episode * 16 * Avg Reward is ==> [-9.59141765]
# Episode * 17 * Avg Reward is ==> [-9.11294281]
# Episode * 18 * Avg Reward is ==> [-8.68479482]
# Episode * 19 * Avg Reward is ==> [-8.29943141]
# Episode * 20 * Avg Reward is ==> [-7.95075227]
# Episode * 21 * Avg Reward is ==> [-7.63365921]
# Episode * 22 * Avg Reward is ==> [-7.34409549]
# Episode * 23 * Avg Reward is ==> [-7.0786481]
# Episode * 24 * Avg Reward is ==> [-6.83440855]
# Episode * 25 * Avg Reward is ==> [-6.60899747]
# Episode * 26 * Avg Reward is ==> [-6.40028511]
# Episode * 27 * Avg Reward is ==> [-6.2065045]
# Episode * 28 * Avg Reward is ==> [-6.02618092]
# Episode * 29 * Avg Reward is ==> [-5.85793348]
# Episode * 30 * Avg Reward is ==> [-5.70057616]
# Episode * 31 * Avg Reward is ==> [-5.5531454]
# Episode * 32 * Avg Reward is ==> [-5.41470276]
# Episode * 33 * Avg Reward is ==> [-5.28444005]
# Episode * 34 * Avg Reward is ==> [-5.16167782]
# Episode * 35 * Avg Reward is ==> [-5.04571729]
# Episode * 36 * Avg Reward is ==> [-4.9360394]
# Episode * 37 * Avg Reward is ==> [-4.83214832]
# Episode * 38 * Avg Reward is ==> [-4.73362253]
# Episode * 39 * Avg Reward is ==> [-4.64007301]
# Episode * 40 * Avg Reward is ==> [-2.11487645]
# Episode * 41 * Avg Reward is ==> 0.3603022467951055
# Episode * 42 * Avg Reward is ==> 2.246587777819736
# Episode * 43 * Avg Reward is ==> -0.9800803993052851
# Episode * 44 * Avg Reward is ==> -0.9806953106655134
# Episode * 45 * Avg Reward is ==> -0.9812862644747119
# Episode * 46 * Avg Reward is ==> -0.9819281898097889
# Episode * 47 * Avg Reward is ==> -0.9825308431200085
# Episode * 48 * Avg Reward is ==> -0.9831055523012857
# Episode * 49 * Avg Reward is ==> -0.9836510018979474
# Episode * 50 * Avg Reward is ==> -0.984122136122482
# Episode * 51 * Avg Reward is ==> -0.9845633450769096
# Episode * 52 * Avg Reward is ==> -0.9849230850994737
# Episode * 53 * Avg Reward is ==> -0.9852486515394739
# Episode * 54 * Avg Reward is ==> -0.9855957631175197
# Episode * 55 * Avg Reward is ==> -0.9859473260566567
# Episode * 56 * Avg Reward is ==> -0.9862858653240723
# Episode * 57 * Avg Reward is ==> -0.9865883950279377
# Episode * 58 * Avg Reward is ==> -0.986896359156751
# Episode * 59 * Avg Reward is ==> -0.9872073833713173
# Episode * 60 * Avg Reward is ==> -0.9875387367751782
# Episode * 61 * Avg Reward is ==> -0.9879438630085925
# Episode * 62 * Avg Reward is ==> -0.9883714521532172
# Episode * 63 * Avg Reward is ==> -0.988808040837931
# Episode * 64 * Avg Reward is ==> -0.989242716176447
# Episode * 65 * Avg Reward is ==> -0.9896718269170499
# Episode * 66 * Avg Reward is ==> -0.9900822167719804
# Episode * 67 * Avg Reward is ==> -0.9904867608396175
# Episode * 68 * Avg Reward is ==> -0.9908174787336985
# Episode * 69 * Avg Reward is ==> -0.9911205190436547
# Episode * 70 * Avg Reward is ==> -0.9914107042292122
# Episode * 71 * Avg Reward is ==> -0.9916389143578653
# Episode * 72 * Avg Reward is ==> -0.9918327370892396
# Episode * 73 * Avg Reward is ==> -0.992021861267828
# Episode * 74 * Avg Reward is ==> -0.9921823116291766
# Episode * 75 * Avg Reward is ==> -0.9923901803720818
# Episode * 76 * Avg Reward is ==> -0.9925933151360308
# Episode * 77 * Avg Reward is ==> -0.992786869269586
# Episode * 78 * Avg Reward is ==> -0.9929573075954977
# Episode * 79 * Avg Reward is ==> -0.9930835283204656
# Episode * 80 * Avg Reward is ==> -0.9932069574353818
# Episode * 81 * Avg Reward is ==> -0.9933224436914994
# Episode * 82 * Avg Reward is ==> -0.9934084300493288
# Episode * 83 * Avg Reward is ==> -0.9934771654651489
# Episode * 84 * Avg Reward is ==> -0.9935145610277653
# Episode * 85 * Avg Reward is ==> -0.993549267833852
# Episode * 86 * Avg Reward is ==> -0.9935655551845242
# Episode * 87 * Avg Reward is ==> -0.9935808013336317
# Episode * 88 * Avg Reward is ==> -0.9936207899037223
# Episode * 89 * Avg Reward is ==> -0.9936585559557967
# Episode * 90 * Avg Reward is ==> -0.993725964394425
# Episode * 91 * Avg Reward is ==> -0.9938079059279913
# Episode * 92 * Avg Reward is ==> -0.9939282023533111
# Episode * 93 * Avg Reward is ==> -0.9940645096992456
# Episode * 94 * Avg Reward is ==> -0.9942056499483467
# Episode * 95 * Avg Reward is ==> -0.9943797517272415
# Episode * 96 * Avg Reward is ==> -0.9945339132467204
# Episode * 97 * Avg Reward is ==> -0.9947160136360539
# Episode * 98 * Avg Reward is ==> -0.9949159044568109
# Episode * 99 * Avg Reward is ==> -0.9951250086181116

# %%
# Save the weights
actor_model.save_weights("v2test100_actor.h5")
critic_model.save_weights("v2test100_critic.h5")

target_actor.save_weights("v2test100_target_actor.h5")
target_critic.save_weights("v2test100_target_critic.h5")

# %% [raw]
# actor_model.save("v2test100_actor.h5")
# critic_model.save("v2test100_critic.h5")
#
# target_actor.save("v2test100_target_actor.h5")
# target_critic.save("v2test100_target_critic.h5")

# %%
print(type(actor_model))
# Out:
# <class 'tensorflow.python.keras.engine.functional.Functional'>

# %%
print(actor_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1024
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# _________________________________________________________________
# tf.math.multiply (TFOpLambda (None, 1)                 0
# =================================================================
# Total params: 67,073
# Trainable params: 67,073
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Simulation

# %% [raw]
# # initial observation
# observation = env.reset()
# print(observation)
#
# rewardlst = []
# voltagelst = []
# powerlst = []
#
# num_steps = 1000
# for t in range(num_steps):
#     action = env.action_space.sample()
#     print(action)
#
#     observation, reward, done, info = env.step(action)
#     print(observation)
#     voltagelst.append(observation[0])
#     powerlst.append(observation[1])
#
#     print(reward)
# #     print(type(reward))
#     rewardlst.append(np.mean(reward))
#
#     print(done)
#     print(info)
#     print("Episode finished after {} timesteps".format(t+1))
#     print()

# %%
observation = env.reset()
print(observation)

rewardlst = []
voltagelst = []
powerlst = []

num_steps = 1000
for t in range(num_steps):
    tf_observation = tf.expand_dims(tf.convert_to_tensor(observation), 0)    
    action = policy(tf_observation, ou_noise)
    print(action)
    
    observation, reward, done, info = env.step(action)
    print(observation)
    voltagelst.append(observation[0])
    powerlst.append(observation[1])
    
    print(reward)
    rewardlst.append(np.mean(reward))
    
    print(done)
    print(info)
    print("Episode finished after {} timesteps".format(t+1))
    print()
# Out:
# [0. 0. 0.]
# [array(0.27423973)]
# [0.27423973 4.11877035 0.27423973]
# [-0.99830357]
# True
# {'Corriente': array([15.01886816]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.27423973)]}
# Episode finished after 1 timesteps
#
# [array(0.16742424)]
# [0.44166397 6.6332805  0.16742424]
# [-0.99559996]
# True
# {'Corriente': array([15.01884013]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.16742424)]}
# Episode finished after 2 timesteps
#
# [array(0.16842358)]
# [0.61008754 9.1627892  0.16842358]
# [-0.99160433]
# True
# {'Corriente': array([15.01881047]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.16842358)]}
# Episode finished after 3 timesteps
#
# [array(0.18347968)]
# [ 0.79356722 11.9184087   0.18347968]
# [-0.98579515]
# True
# {'Corriente': array([15.0187764]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.18347968)]}
# Episode finished after 4 timesteps
#
# [array(0.18020319)]
# [ 0.97377042 14.62480575  0.18020319]
# [-0.97861151]
# True
# {'Corriente': array([15.01874105]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.18020319)]}
# Episode finished after 5 timesteps
#
# [array(0.14202999)]
# [ 1.11580041 16.75788481  0.14202999]
# [-0.97191733]
# True
# {'Corriente': array([15.01871179]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.14202999)]}
# Episode finished after 6 timesteps
#
# [array(0.13962054)]
# [ 1.25542095 18.85476775  0.13962054]
# [-0.96444977]
# True
# {'Corriente': array([15.01868179]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.13962054)]}
# Episode finished after 7 timesteps
#
# [array(0.12265879)]
# [ 1.37807974 20.69690336  0.12265879]
# [-0.95716382]
# True
# {'Corriente': array([15.01865437]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.12265879)]}
# Episode finished after 8 timesteps
#
# [array(0.100726)]
# [ 1.47880574 22.20963787  0.100726  ]
# [-0.9506732]
# True
# {'Corriente': array([15.01863107]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.100726)]}
# Episode finished after 9 timesteps
#
# [array(0.10016587)]
# [ 1.57897161 23.71395445  0.10016587]
# [-0.94376484]
# True
# {'Corriente': array([15.0186072]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.10016587)]}
# Episode finished after 10 timesteps
#
# [array(0.12572258)]
# [ 1.70469419 25.60207956  0.12572258]
# [-0.93445335]
# True
# {'Corriente': array([15.01857619]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.12572258)]}
# Episode finished after 11 timesteps
#
# [array(0.12097274)]
# [ 1.82566693 27.41886138  0.12097274]
# [-0.9248206]
# True
# {'Corriente': array([15.01854523]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.12097274)]}
# Episode finished after 12 timesteps
#
# [array(0.09753137)]
# [ 1.9231983  28.88359109  0.09753137]
# [-0.91657382]
# True
# {'Corriente': array([15.01851942]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.09753137)]}
# Episode finished after 13 timesteps
#
# [array(0.06439623)]
# [ 1.98759453 29.8506924   0.06439623]
# [-0.91089362]
# True
# {'Corriente': array([15.01850196]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.06439623)]}
# Episode finished after 14 timesteps
#
# [array(0.06832382)]
# [ 2.05591836 30.87677505  0.06832382]
# [-0.90466248]
# True
# {'Corriente': array([15.01848307]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.06832382)]}
# Episode finished after 15 timesteps
#
# [array(0.09295949)]
# [ 2.14887785 32.27282894  0.09295949]
# [-0.89584645]
# True
# {'Corriente': array([15.01845672]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.09295949)]}
# Episode finished after 16 timesteps
#
# [array(0.09280683)]
# [ 2.24168468 33.66658365  0.09280683]
# [-0.88665611]
# True
# {'Corriente': array([15.01842967]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.09280683)]}
# Episode finished after 17 timesteps
#
# [array(0.11123322)]
# [ 2.3529179  35.33705326  0.11123322]
# [-0.87512927]
# True
# {'Corriente': array([15.01839624]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.11123322)]}
# Episode finished after 18 timesteps
#
# [array(0.13435775)]
# [ 2.48727565 37.35478699  0.13435775]
# [-0.86046199]
# True
# {'Corriente': array([15.01835432]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.13435775)]}
# Episode finished after 19 timesteps
#
# [array(0.1353385)]
# [ 2.62261415 39.38723326  0.1353385 ]
# [-0.84486459]
# True
# {'Corriente': array([15.01831035]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.1353385)]}
# Episode finished after 20 timesteps
#
# [array(0.15172128)]
# [ 2.77433543 41.66568776  0.15172128]
# [-0.82639705]
# True
# {'Corriente': array([15.01825887]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.15172128)]}
# Episode finished after 21 timesteps
#
# [array(0.15094437)]
# [ 2.9252798  43.93245253  0.15094437]
# [-0.80699396]
# True
# {'Corriente': array([15.01820526]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.15094437)]}
# Episode finished after 22 timesteps
#
# [array(0.15868292)]
# [ 3.08396272 46.31540306  0.15868292]
# [-0.78548834]
# True
# {'Corriente': array([15.01814621]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.15868292)]}
# Episode finished after 23 timesteps
#
# [array(0.17410343)]
# [ 3.25806615 48.9298919   0.17410343]
# [-0.76058657]
# True
# {'Corriente': array([15.01807808]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.17410343)]}
# Episode finished after 24 timesteps
#
# [array(0.1679401)]
# [ 3.42600626 51.45179241  0.1679401 ]
# [-0.73527131]
# True
# {'Corriente': array([15.01800888]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.1679401)]}
# Episode finished after 25 timesteps
#
# [array(0.16845611)]
# [ 3.59446237 53.98140529  0.16845611]
# [-0.70860079]
# True
# {'Corriente': array([15.01793585]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.16845611)]}
# Episode finished after 26 timesteps
#
# [array(0.16427981)]
# [ 3.75874218 56.44826739  0.16427981]
# [-0.68135931]
# True
# {'Corriente': array([15.01786096]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.16427981)]}
# Episode finished after 27 timesteps
#
# [array(0.15261243)]
# [ 3.91135461 58.73989427  0.15261243]
# [-0.65496248]
# True
# {'Corriente': array([15.01778798]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.15261243)]}
# Episode finished after 28 timesteps
#
# [array(0.12170995)]
# [ 4.03306456 60.56746391  0.12170995]
# [-0.63315823]
# True
# {'Corriente': array([15.01772733]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.12170995)]}
# Episode finished after 29 timesteps
#
# [array(0.13145548)]
# [ 4.16452004 62.54134294  0.13145548]
# [-0.60885804]
# True
# {'Corriente': array([15.01765926]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.13145548)]}
# Episode finished after 30 timesteps
#
# [array(0.13829071)]
# [ 4.30281075 64.61782478  0.13829071]
# [-0.58245367]
# True
# {'Corriente': array([15.01758468]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.13829071)]}
# Episode finished after 31 timesteps
#
# [array(0.16052775)]
# [ 4.4633385  67.02815968  0.16052775]
# [-0.55072258]
# True
# {'Corriente': array([15.01749411]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.16052775)]}
# Episode finished after 32 timesteps
#
# [array(0.20034796)]
# [ 4.66368647 70.03632732  0.20034796]
# [-0.50949129]
# True
# {'Corriente': array([15.01737473]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.20034796)]}
# Episode finished after 33 timesteps
#
# [array(0.2596611)]
# [ 4.92334757 73.93493882  0.2596611 ]
# [-0.45336248]
# True
# {'Corriente': array([15.01720888]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.2596611)]}
# Episode finished after 34 timesteps
#
# [array(0.28234577)]
# [ 5.20569334 78.17396533  0.28234577]
# [-0.38888311]
# True
# {'Corriente': array([15.01701315]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.28234577)]}
# Episode finished after 35 timesteps
#
# [array(0.25597002)]
# [ 5.46166336 82.01681936  0.25597002]
# [-0.32732413]
# True
# {'Corriente': array([15.0168207]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.25597002)]}
# Episode finished after 36 timesteps
#
# [array(0.24687334)]
# [ 5.70853669 85.72292886  0.24687334]
# [-0.26515795]
# True
# {'Corriente': array([15.01662045]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.24687334)]}
# Episode finished after 37 timesteps
#
# [array(0.23744714)]
# [ 5.94598383 89.28735041  0.23744714]
# [-0.20277691]
# True
# {'Corriente': array([15.01641325]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.23744714)]}
# Episode finished after 38 timesteps
#
# [array(0.25206924)]
# [ 6.19805307 93.0710583   0.25206924]
# [-0.13377781]
# True
# {'Corriente': array([15.01617641]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.25206924)]}
# Episode finished after 39 timesteps
#
# [array(0.24266717)]
# [ 6.44072024 96.71340908  0.24266717]
# [-0.06465165]
# True
# {'Corriente': array([15.01593074]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.24266717)]}
# Episode finished after 40 timesteps
#
# [array(0.22725376)]
# [  6.667974   100.12418899   0.22725376]
# [0.00248532]
# True
# {'Corriente': array([15.01568376]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.22725376)]}
# Episode finished after 41 timesteps
#
# [array(0.20117465)]
# [  6.86914866 103.14336184   0.20117465]
# [0.06385531]
# True
# {'Corriente': array([15.01545053]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.20117465)]}
# Episode finished after 42 timesteps
#
# [array(0.2261036)]
# [  7.09525225 106.53642535   0.2261036 ]
# [0.13500099]
# True
# {'Corriente': array([15.01517093]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.2261036)]}
# Episode finished after 43 timesteps
#
# [array(0.22836531)]
# [  7.32361756 109.96315448   0.22836531]
# [0.20918953]
# True
# {'Corriente': array([15.01486848]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.22836531)]}
# Episode finished after 44 timesteps
#
# [array(0.23164571)]
# [  7.55526327 113.43879973   0.23164571]
# [0.28683613]
# True
# {'Corriente': array([15.01453962]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.23164571)]}
# Episode finished after 45 timesteps
#
# [array(0.26886894)]
# [  7.82413221 117.47252195   0.26886894]
# [0.37997934]
# True
# {'Corriente': array([15.01412793]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.26886894)]}
# Episode finished after 46 timesteps
#
# [array(0.27430606)]
# [  8.09843827 121.58729609   0.27430606]
# [0.47834706]
# True
# {'Corriente': array([15.01367203]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.27430606)]}
# Episode finished after 47 timesteps
#
# [array(0.26194331)]
# [  8.36038157 125.51608052   0.26194331]
# [0.57542865]
# True
# {'Corriente': array([15.01319998]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.26194331)]}
# Episode finished after 48 timesteps
#
# [array(0.28341195)]
# [  8.64379352 129.76620713   0.28341195]
# [0.68392685]
# True
# {'Corriente': array([15.01264541]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.28341195)]}
# Episode finished after 49 timesteps
#
# [array(0.27701602)]
# [  8.92080955 133.91968807   0.27701602]
# [0.79344829]
# True
# {'Corriente': array([15.0120555]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.27701602)]}
# Episode finished after 50 timesteps
#
# [array(0.30632137)]
# [  9.22713092 138.51162809   0.30632137]
# [0.91854711]
# True
# {'Corriente': array([15.01134311]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.30632137)]}
# Episode finished after 51 timesteps
#
# [array(0.28610671)]
# [  9.51323762 142.79955232   0.28610671]
# [1.03917121]
# True
# {'Corriente': array([15.01061552]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.28610671)]}
# Episode finished after 52 timesteps
#
# [array(0.30108717)]
# [  9.81432479 147.31084465   0.30108717]
# [1.1700485]
# True
# {'Corriente': array([15.00977885]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.30108717)]}
# Episode finished after 53 timesteps
#
# [array(0.32388681)]
# [ 10.1382116  152.16228616   0.32388681]
# [1.31533613]
# True
# {'Corriente': array([15.00878973]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.32388681)]}
# Episode finished after 54 timesteps
#
# [array(0.33651028)]
# [ 10.47472187 157.20100493   0.33651028]
# [1.47121559]
# True
# {'Corriente': array([15.00765431]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.33651028)]}
# Episode finished after 55 timesteps
#
# [array(0.33544023)]
# [ 10.81016211 162.22163497   0.33544023]
# [1.63158589]
# True
# {'Corriente': array([15.00640169]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.33544023)]}
# Episode finished after 56 timesteps
#
# [array(0.34472669)]
# [ 11.1548888  167.37882953   0.34472669]
# [1.80156726]
# True
# {'Corriente': array([15.00497518]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.34472669)]}
# Episode finished after 57 timesteps
#
# [array(0.3335171)]
# [ 11.48840589 172.36568123   0.3335171 ]
# [1.97099281]
# True
# {'Corriente': array([15.00344633]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.3335171)]}
# Episode finished after 58 timesteps
#
# [array(0.3486278)]
# [ 11.83703369 177.5753303    0.3486278 ]
# [2.15329979]
# True
# {'Corriente': array([15.00167483]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.3486278)]}
# Episode finished after 59 timesteps
#
# [array(0.33826608)]
# [ 12.17529977 182.62667499   0.33826608]
# [2.33525024]
# True
# {'Corriente': array([14.99976825]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.33826608)]}
# Episode finished after 60 timesteps
#
# [array(0.35210981)]
# [ 12.52740958 187.88064708   0.35210981]
# [2.52991375]
# True
# {'Corriente': array([14.99756561]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.35210981)]}
# Episode finished after 61 timesteps
#
# [array(0.33782114)]
# [ 12.86523072 192.91697142   0.33782114]
# [2.72169579]
# True
# {'Corriente': array([14.9952205]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.33782114)]}
# Episode finished after 62 timesteps
#
# [array(0.33811437)]
# [ 13.20334509 197.95275222   0.33811437]
# [2.91852921]
# True
# {'Corriente': array([14.99262125]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.33811437)]}
# Episode finished after 63 timesteps
#
# [array(0.33469367)]
# [ 13.53803877 202.93213213   0.33469367]
# [3.11814503]
# True
# {'Corriente': array([14.98977331]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.33469367)]}
# Episode finished after 64 timesteps
#
# [array(0.3337747)]
# [ 13.87181346 207.89175902   0.3337747 ]
# [3.32189835]
# True
# {'Corriente': array([14.98663167]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.3337747)]}
# Episode finished after 65 timesteps
#
# [array(0.33341462)]
# [ 14.20522809 212.83921859   0.33341462]
# [3.5300533]
# True
# {'Corriente': array([14.98316094]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.33341462)]}
# Episode finished after 66 timesteps
#
# [array(0.34442661)]
# [ 14.54965469 217.94203067   0.34442661]
# [3.74987287]
# True
# {'Corriente': array([14.97918921]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.34442661)]}
# Episode finished after 67 timesteps
#
# [array(0.33592988)]
# [ 14.88558457 222.91009008   0.33592988]
# [3.96889083]
# True
# {'Corriente': array([14.97489662]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.33592988)]}
# Episode finished after 68 timesteps
#
# [array(0.32414558)]
# [ 15.20973015 227.69453984   0.32414558]
# [4.18448035]
# True
# {'Corriente': array([14.97032082]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.32414558)]}
# Episode finished after 69 timesteps
#
# [array(0.34758093)]
# [ 15.55731107 232.81345349   0.34758093]
# [4.42021041]
# True
# {'Corriente': array([14.96489029]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.34758093)]}
# Episode finished after 70 timesteps
#
# [array(0.35611856)]
# [ 15.91342964 238.04426358   0.35611856]
# [4.66650714]
# True
# {'Corriente': array([14.95870274]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.35611856)]}
# Episode finished after 71 timesteps
#
# [array(0.36441125)]
# [ 16.27784089 243.38047415   0.36441125]
# [4.92340552]
# True
# {'Corriente': array([14.95164351]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.36441125)]}
# Episode finished after 72 timesteps
#
# [array(0.3600141)]
# [ 16.63785499 248.63383786   0.3600141 ]
# [5.18187853]
# True
# {'Corriente': array([14.94386374]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.3600141)]}
# Episode finished after 73 timesteps
#
# [array(0.37939828)]
# [ 17.01725327 254.14751386   0.37939828]
# [5.45909588]
# True
# {'Corriente': array([14.93469656]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.37939828)]}
# Episode finished after 74 timesteps
#
# [array(0.39877868)]
# [ 17.41603195 259.9144154    0.39877868]
# [5.75555033]
# True
# {'Corriente': array([14.92385959]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.39877868)]}
# Episode finished after 75 timesteps
#
# [array(0.37267437)]
# [ 17.78870632 265.27376665   0.37267437]
# [6.03701713]
# True
# {'Corriente': array([14.91248222]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.37267437)]}
# Episode finished after 76 timesteps
#
# [array(0.38580611)]
# [ 18.17451243 270.78705536   0.38580611]
# [6.33256293]
# True
# {'Corriente': array([14.89927481]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.38580611)]}
# Episode finished after 77 timesteps
#
# [array(0.3906667)]
# [ 18.56517914 276.32854228   0.3906667 ]
# [6.63574633]
# True
# {'Corriente': array([14.88423786]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.3906667)]}
# Episode finished after 78 timesteps
#
# [array(0.396668)]
# [ 18.96184713 281.90659642   0.396668  ]
# [6.94713291]
# True
# {'Corriente': array([14.86704299]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.396668)]}
# Episode finished after 79 timesteps
#
# [array(0.42325786)]
# [ 19.38510499 287.79663131   0.42325786]
# [7.2826901]
# True
# {'Corriente': array([14.84627664]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.42325786)]}
# Episode finished after 80 timesteps
#
# [array(0.39950992)]
# [ 19.78461491 293.28881849   0.39950992]
# [7.60183311]
# True
# {'Corriente': array([14.82408527]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.39950992)]}
# Episode finished after 81 timesteps
# [array(0.37414127)]
# [ 20.15875618 298.36431972   0.37414127]
# [7.90212673]
# True
# {'Corriente': array([14.80073061]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.37414127)]}
# Episode finished after 82 timesteps
#
# [array(0.37852005)]
# [ 20.53727623 303.42305098   0.37852005]
# [8.20655479]
# True
# {'Corriente': array([14.77425962]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.37852005)]}
# Episode finished after 83 timesteps
#
# [array(0.3661659)]
# [ 20.90344213 308.23394972   0.3661659 ]
# [8.50081678]
# True
# {'Corriente': array([14.74560734]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.3661659)]}
# Episode finished after 84 timesteps
#
# [array(0.35618645)]
# [ 21.25962857 312.82536016   0.35618645]
# [8.7859706]
# True
# {'Corriente': array([14.71452613]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.35618645)]}
# Episode finished after 85 timesteps
#
# [array(0.37872713)]
# [ 21.63835571 317.59910201   0.37872713]
# [9.08691896]
# True
# {'Corriente': array([14.67759872]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.37872713)]}
# Episode finished after 86 timesteps
#
# [array(0.39976332)]
# [ 22.03811902 322.5004877    0.39976332]
# [9.40065646]
# True
# {'Corriente': array([14.63375742]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.39976332)]}
# Episode finished after 87 timesteps
#
# [array(0.40070962)]
# [ 22.43882864 327.25166051   0.40070962]
# [9.70936493]
# True
# {'Corriente': array([14.58416862]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.40070962)]}
# Episode finished after 88 timesteps
#
# [array(0.42239587)]
# [ 22.86122451 332.05876537   0.42239587]
# [10.02630237]
# True
# {'Corriente': array([14.52497722]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.42239587)]}
# Episode finished after 89 timesteps
#
# [array(0.41451475)]
# [ 23.27573927 336.54555891   0.41451475]
# [10.32629132]
# True
# {'Corriente': array([14.45907067]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.41451475)]}
# Episode finished after 90 timesteps
#
# [array(0.459595)]
# [ 23.73533427 341.21152238   0.459595  ]
# [10.6425303]
# True
# {'Corriente': array([14.37567799]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.459595)]}
# Episode finished after 91 timesteps
#
# [array(0.43956085)]
# [ 24.17489512 345.32226184   0.43956085]
# [10.92474645]
# True
# {'Corriente': array([14.2843334]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.43956085)]}
# Episode finished after 92 timesteps
#
# [array(0.43382629)]
# [ 24.60872141 348.98806461   0.43382629]
# [11.17926692]
# True
# {'Corriente': array([14.18147895]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.43382629)]}
# Episode finished after 93 timesteps
#
# [array(0.43737262)]
# [ 25.04609403 352.2284703    0.43737262]
# [11.40648953]
# True
# {'Corriente': array([14.06320961]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.43737262)]}
# Episode finished after 94 timesteps
#
# [array(0.48165361)]
# [ 25.52774764 355.18193412   0.48165361]
# [11.61542063]
# True
# {'Corriente': array([13.91356336]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.48165361)]}
# Episode finished after 95 timesteps
#
# [array(0.51243797)]
# [ 26.04018561 357.49417069   0.51243797]
# [11.78020821]
# True
# {'Corriente': array([13.72855693]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.51243797)]}
# Episode finished after 96 timesteps
#
# [array(0.51988467)]
# [ 26.56007028 358.80551691   0.51988467]
# [11.8741399]
# True
# {'Corriente': array([13.50920811]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.51988467)]}
# Episode finished after 97 timesteps
#
# [array(0.52566045)]
# [ 27.08573073 358.87247193   0.52566045]
# [11.87894511]
# True
# {'Corriente': array([13.24950305]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.52566045)]}
# Episode finished after 98 timesteps
#
# [array(0.5381706)]
# [ 27.62390133 357.37839264   0.5381706 ]
# [11.77193155]
# True
# {'Corriente': array([12.93728892]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.5381706)]}
# Episode finished after 99 timesteps
#
# [array(0.55021366)]
# [ 28.17411498 353.89727581   0.55021366]
# [11.52432818]
# True
# {'Corriente': array([12.56107871]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.55021366)]}
# Episode finished after 100 timesteps
#
# [array(0.56709714)]
# [ 28.74121212 347.82791661   0.56709714]
# [11.09842596]
# True
# {'Corriente': array([12.1020615]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.56709714)]}
# Episode finished after 101 timesteps
#
# [array(0.53697198)]
# [ 29.2781841  339.29546173   0.53697198]
# [10.51214103]
# True
# {'Corriente': array([11.58867847]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.53697198)]}
# Episode finished after 102 timesteps
#
# [array(0.56726768)]
# [ 29.84545178 326.74460205   0.56726768]
# [9.6762035]
# True
# {'Corriente': array([10.94788595]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.56726768)]}
# Episode finished after 103 timesteps
#
# [array(0.55729223)]
# [ 30.402744   310.1668173    0.55729223]
# [8.62034546]
# True
# {'Corriente': array([10.20193497]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.55729223)]}
# Episode finished after 104 timesteps
#
# [array(0.58874079)]
# [ 30.9914848  287.13441085   0.58874079]
# [7.24461699]
# True
# {'Corriente': array([9.26494528]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.58874079)]}
# Episode finished after 105 timesteps
#
# [array(0.55504006)]
# [ 31.54652486 259.16376357   0.55504006]
# [5.71658563]
# True
# {'Corriente': array([8.21528725]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.55504006)]}
# Episode finished after 106 timesteps
#
# [array(0.55019853)]
# [ 32.09672339 224.22493071   0.55019853]
# [4.02768196]
# True
# {'Corriente': array([6.98591342]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.55019853)]}
# Episode finished after 107 timesteps
#
# [array(0.59289361)]
# [ 32.68961701 176.8958129    0.59289361]
# [2.12921286]
# True
# {'Corriente': array([5.41137612]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.59289361)]}
# Episode finished after 108 timesteps
#
# [array(0.61479178)]
# [ 33.30440878 114.96751307   0.61479178]
# [0.32175291]
# True
# {'Corriente': array([3.45202084]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.61479178)]}
# Episode finished after 109 timesteps
#
# [array(0.58765607)]
# [33.89206485 40.89786442  0.58765607]
# [-0.83273647]
# True
# {'Corriente': array([1.20670914]), 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.58765607)]}
# Episode finished after 110 timesteps
#
# [array(0.63626958)]
# [ 34.5        -54.36214217   0.60793515]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(0.63626958)]}
# Episode finished after 111 timesteps
#
# [array(6.41747741)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.41747741)]}
# Episode finished after 112 timesteps
#
# [array(6.4037052)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.4037052)]}
# Episode finished after 113 timesteps
#
# [array(6.40577447)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.40577447)]}
# Episode finished after 114 timesteps
#
# [array(6.42350308)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.42350308)]}
# Episode finished after 115 timesteps
#
# [array(6.39588565)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.39588565)]}
# Episode finished after 116 timesteps
#
# [array(6.4155216)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.4155216)]}
# Episode finished after 117 timesteps
#
# [array(6.40498002)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.40498002)]}
# Episode finished after 118 timesteps
#
# [array(6.4027872)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.4027872)]}
# Episode finished after 119 timesteps
#
# [array(6.42759338)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.42759338)]}
# Episode finished after 120 timesteps
#
# [array(6.43681827)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.43681827)]}
# Episode finished after 121 timesteps
#
# [array(6.42517848)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.42517848)]}
# Episode finished after 122 timesteps
#
# [array(6.44056703)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.44056703)]}
# Episode finished after 123 timesteps
#
# [array(6.44098912)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.44098912)]}
# Episode finished after 124 timesteps
#
# [array(6.44052806)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.44052806)]}
# Episode finished after 125 timesteps
#
# [array(6.43572824)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.43572824)]}
# Episode finished after 126 timesteps
#
# [array(6.47741652)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.47741652)]}
# Episode finished after 127 timesteps
#
# [array(6.49435201)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.49435201)]}
# Episode finished after 128 timesteps
#
# [array(6.48278979)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.48278979)]}
# Episode finished after 129 timesteps
#
# [array(6.50703924)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.50703924)]}
# Episode finished after 130 timesteps
#
# [array(6.50917756)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.50917756)]}
# Episode finished after 131 timesteps
#
# [array(6.48981032)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.48981032)]}
# Episode finished after 132 timesteps
#
# [array(6.48161913)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.48161913)]}
# Episode finished after 133 timesteps
#
# [array(6.48685909)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.48685909)]}
# Episode finished after 134 timesteps
#
# [array(6.45800537)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.45800537)]}
# Episode finished after 135 timesteps
#
# [array(6.4444822)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.4444822)]}
# Episode finished after 136 timesteps
#
# [array(6.45118844)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.45118844)]}
# Episode finished after 137 timesteps
#
# [array(6.43170952)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.43170952)]}
# Episode finished after 138 timesteps
#
# [array(6.40844058)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.40844058)]}
# Episode finished after 139 timesteps
#
# [array(6.38761607)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.38761607)]}
# Episode finished after 140 timesteps
#
# [array(6.37338341)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.37338341)]}
# Episode finished after 141 timesteps
#
# [array(6.36132356)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.36132356)]}
# Episode finished after 142 timesteps
#
# [array(6.35535697)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.35535697)]}
# Episode finished after 143 timesteps
#
# [array(6.35436845)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.35436845)]}
# Episode finished after 144 timesteps
#
# [array(6.33874944)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.33874944)]}
# Episode finished after 145 timesteps
#
# [array(6.32900904)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.32900904)]}
# Episode finished after 146 timesteps
#
# [array(6.342325)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.342325)]}
# Episode finished after 147 timesteps
#
# [array(6.35606999)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.35606999)]}
# Episode finished after 148 timesteps
#
# [array(6.32566265)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.32566265)]}
# Episode finished after 149 timesteps
#
# [array(6.34971107)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.34971107)]}
# Episode finished after 150 timesteps
#
# [array(6.35743569)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.35743569)]}
# Episode finished after 151 timesteps
#
# [array(6.35706643)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.35706643)]}
# Episode finished after 152 timesteps
#
# [array(6.34913828)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.34913828)]}
# Episode finished after 153 timesteps
#
# [array(6.37019607)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.37019607)]}
# Episode finished after 154 timesteps
#
# [array(6.3424588)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.3424588)]}
# Episode finished after 155 timesteps
#
# [array(6.32637442)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.32637442)]}
# Episode finished after 156 timesteps
#
# [array(6.29546356)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.29546356)]}
# Episode finished after 157 timesteps
#
# [array(6.30331985)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.30331985)]}
# Episode finished after 158 timesteps
#
# [array(6.28534615)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.28534615)]}
# Episode finished after 159 timesteps
#
# [array(6.28611423)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.28611423)]}
# Episode finished after 160 timesteps
#
# [array(6.27455345)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.27455345)]}
# Episode finished after 161 timesteps
#
# [array(6.27353839)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.27353839)]}
# Episode finished after 162 timesteps
#
# [array(6.28614512)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.28614512)]}
# Episode finished after 163 timesteps
#
# [array(6.29016681)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.29016681)]}
# Episode finished after 164 timesteps
#
# [array(6.27750319)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.27750319)]}
# Episode finished after 165 timesteps
#
# [array(6.25361379)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.25361379)]}
# Episode finished after 166 timesteps
#
# [array(6.27971463)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.27971463)]}
# Episode finished after 167 timesteps
#
# [array(6.26263845)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.26263845)]}
# Episode finished after 168 timesteps
#
# [array(6.30944889)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.30944889)]}
# Episode finished after 169 timesteps
#
# [array(6.3290383)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.3290383)]}
# Episode finished after 170 timesteps
#
# [array(6.32086531)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.32086531)]}
# Episode finished after 171 timesteps
#
# [array(6.30177069)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.30177069)]}
# Episode finished after 172 timesteps
#
# [array(6.26898529)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.26898529)]}
# Episode finished after 173 timesteps
#
# [array(6.29727404)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.29727404)]}
# Episode finished after 174 timesteps
#
# [array(6.30826362)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.30826362)]}
# Episode finished after 175 timesteps
#
# [array(6.334449)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.334449)]}
# Episode finished after 176 timesteps
#
# [array(6.30986108)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.30986108)]}
# Episode finished after 177 timesteps
#
# [array(6.29003127)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.29003127)]}
# Episode finished after 178 timesteps
#
# [array(6.29206867)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.29206867)]}
# Episode finished after 179 timesteps
#
# [array(6.29532082)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.29532082)]}
# Episode finished after 180 timesteps
#
# [array(6.25575686)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.25575686)]}
# Episode finished after 181 timesteps
#
# [array(6.25546895)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.25546895)]}
# Episode finished after 182 timesteps
#
# [array(6.24308526)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.24308526)]}
# Episode finished after 183 timesteps
#
# [array(6.25234123)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.25234123)]}
# Episode finished after 184 timesteps
#
# [array(6.28069317)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.28069317)]}
# Episode finished after 185 timesteps
#
# [array(6.28639358)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.28639358)]}
# Episode finished after 186 timesteps
#
# [array(6.27793904)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.27793904)]}
# Episode finished after 187 timesteps
#
# [array(6.3274571)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.3274571)]}
# Episode finished after 188 timesteps
#
# [array(6.31601176)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.31601176)]}
# Episode finished after 189 timesteps
#
# [array(6.30035094)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.30035094)]}
# Episode finished after 190 timesteps
#
# [array(6.29199312)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.29199312)]}
# Episode finished after 191 timesteps
#
# [array(6.28635597)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.28635597)]}
# Episode finished after 192 timesteps
# [array(6.27662254)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.27662254)]}
# Episode finished after 193 timesteps
#
# [array(6.29533432)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.29533432)]}
# Episode finished after 194 timesteps
#
# [array(6.28241607)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.28241607)]}
# Episode finished after 195 timesteps
#
# [array(6.30817904)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.30817904)]}
# Episode finished after 196 timesteps
#
# [array(6.30181346)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.30181346)]}
# Episode finished after 197 timesteps
#
# [array(6.30469826)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.30469826)]}
# Episode finished after 198 timesteps
#
# [array(6.30395249)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.30395249)]}
# Episode finished after 199 timesteps
#
# [array(6.28496483)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.28496483)]}
# Episode finished after 200 timesteps
#
# [array(6.26616441)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.26616441)]}
# Episode finished after 201 timesteps
#
# [array(6.2719087)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.2719087)]}
# Episode finished after 202 timesteps
#
# [array(6.22546322)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.22546322)]}
# Episode finished after 203 timesteps
#
# [array(6.2164436)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.2164436)]}
# Episode finished after 204 timesteps
#
# [array(6.21876486)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.21876486)]}
# Episode finished after 205 timesteps
#
# [array(6.21176831)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.21176831)]}
# Episode finished after 206 timesteps
#
# [array(6.20663217)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.20663217)]}
# Episode finished after 207 timesteps
#
# [array(6.18139134)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.18139134)]}
# Episode finished after 208 timesteps
#
# [array(6.16469534)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.16469534)]}
# Episode finished after 209 timesteps
#
# [array(6.16115643)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.16115643)]}
# Episode finished after 210 timesteps
#
# [array(6.12699614)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.12699614)]}
# Episode finished after 211 timesteps
#
# [array(6.13083627)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.13083627)]}
# Episode finished after 212 timesteps
#
# [array(6.10707924)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.10707924)]}
# Episode finished after 213 timesteps
#
# [array(6.08650297)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.08650297)]}
# Episode finished after 214 timesteps
#
# [array(6.10439651)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.10439651)]}
# Episode finished after 215 timesteps
#
# [array(6.08440091)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(6.08440091)]}
# ...
#
# [array(5.68173416)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.68173416)]}
# Episode finished after 928 timesteps
#
# [array(5.69563177)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.69563177)]}
# Episode finished after 929 timesteps
#
# [array(5.68369792)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.68369792)]}
# Episode finished after 930 timesteps
#
# [array(5.67468005)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.67468005)]}
# Episode finished after 931 timesteps
#
# [array(5.65991491)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.65991491)]}
# Episode finished after 932 timesteps
#
# [array(5.68333669)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.68333669)]}
# Episode finished after 933 timesteps
#
# [array(5.66794772)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.66794772)]}
# Episode finished after 934 timesteps
#
# [array(5.64759384)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.64759384)]}
# Episode finished after 935 timesteps
#
# [array(5.63454518)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.63454518)]}
# Episode finished after 936 timesteps
#
# [array(5.6484481)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.6484481)]}
# Episode finished after 937 timesteps
#
# [array(5.64667782)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.64667782)]}
# Episode finished after 938 timesteps
#
# [array(5.62671478)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.62671478)]}
# Episode finished after 939 timesteps
#
# [array(5.63384231)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.63384231)]}
# Episode finished after 940 timesteps
#
# [array(5.66319813)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.66319813)]}
# Episode finished after 941 timesteps
#
# [array(5.62365581)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.62365581)]}
# Episode finished after 942 timesteps
#
# [array(5.63422424)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.63422424)]}
# Episode finished after 943 timesteps
#
# [array(5.67309953)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.67309953)]}
# Episode finished after 944 timesteps
#
# [array(5.6753393)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.6753393)]}
# Episode finished after 945 timesteps
#
# [array(5.65484252)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.65484252)]}
# Episode finished after 946 timesteps
#
# [array(5.61593683)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.61593683)]}
# Episode finished after 947 timesteps
#
# [array(5.62749091)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.62749091)]}
# Episode finished after 948 timesteps
#
# [array(5.59859631)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.59859631)]}
# Episode finished after 949 timesteps
#
# [array(5.57997303)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.57997303)]}
# Episode finished after 950 timesteps
#
# [array(5.5351717)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.5351717)]}
# Episode finished after 951 timesteps
#
# [array(5.53159033)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.53159033)]}
# Episode finished after 952 timesteps
#
# [array(5.53488546)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.53488546)]}
# Episode finished after 953 timesteps
#
# [array(5.54995041)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.54995041)]}
# Episode finished after 954 timesteps
#
# [array(5.51845525)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.51845525)]}
# Episode finished after 955 timesteps
#
# [array(5.53688058)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.53688058)]}
# Episode finished after 956 timesteps
#
# [array(5.54800236)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.54800236)]}
# Episode finished after 957 timesteps
#
# [array(5.55552295)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.55552295)]}
# Episode finished after 958 timesteps
#
# [array(5.52647629)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.52647629)]}
# Episode finished after 959 timesteps
#
# [array(5.53579949)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.53579949)]}
# Episode finished after 960 timesteps
#
# [array(5.56684031)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.56684031)]}
# Episode finished after 961 timesteps
#
# [array(5.58262816)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.58262816)]}
# Episode finished after 962 timesteps
#
# [array(5.59294152)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.59294152)]}
# Episode finished after 963 timesteps
#
# [array(5.59028351)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.59028351)]}
# Episode finished after 964 timesteps
#
# [array(5.62077305)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.62077305)]}
# Episode finished after 965 timesteps
#
# [array(5.64644203)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.64644203)]}
# Episode finished after 966 timesteps
#
# [array(5.63655534)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.63655534)]}
# Episode finished after 967 timesteps
#
# [array(5.65872833)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.65872833)]}
# Episode finished after 968 timesteps
#
# [array(5.70209156)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.70209156)]}
# Episode finished after 969 timesteps
#
# [array(5.69604177)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.69604177)]}
# Episode finished after 970 timesteps
#
# [array(5.73093183)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.73093183)]}
# Episode finished after 971 timesteps
#
# [array(5.74371627)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.74371627)]}
# Episode finished after 972 timesteps
#
# [array(5.74949984)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.74949984)]}
# Episode finished after 973 timesteps
#
# [array(5.73950113)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.73950113)]}
# Episode finished after 974 timesteps
#
# [array(5.74964701)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.74964701)]}
# Episode finished after 975 timesteps
#
# [array(5.75103253)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.75103253)]}
# Episode finished after 976 timesteps
#
# [array(5.74131769)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.74131769)]}
# Episode finished after 977 timesteps
#
# [array(5.76394065)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.76394065)]}
# Episode finished after 978 timesteps
#
# [array(5.76858998)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.76858998)]}
# Episode finished after 979 timesteps
#
# [array(5.73247348)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.73247348)]}
# Episode finished after 980 timesteps
#
# [array(5.69761273)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.69761273)]}
# Episode finished after 981 timesteps
#
# [array(5.7172093)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.7172093)]}
# Episode finished after 982 timesteps
#
# [array(5.72765068)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.72765068)]}
# Episode finished after 983 timesteps
#
# [array(5.69556001)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.69556001)]}
# Episode finished after 984 timesteps
#
# [array(5.70487551)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.70487551)]}
# Episode finished after 985 timesteps
#
# [array(5.69259819)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.69259819)]}
# Episode finished after 986 timesteps
#
# [array(5.67639053)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.67639053)]}
# Episode finished after 987 timesteps
#
# [array(5.67156715)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.67156715)]}
# Episode finished after 988 timesteps
#
# [array(5.64322922)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.64322922)]}
# Episode finished after 989 timesteps
#
# [array(5.64012763)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.64012763)]}
# Episode finished after 990 timesteps
#
# [array(5.6377041)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.6377041)]}
# Episode finished after 991 timesteps
#
# [array(5.65066506)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.65066506)]}
# Episode finished after 992 timesteps
#
# [array(5.660051)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.660051)]}
# Episode finished after 993 timesteps
#
# [array(5.66165884)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.66165884)]}
# Episode finished after 994 timesteps
#
# [array(5.68332296)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.68332296)]}
# Episode finished after 995 timesteps
#
# [array(5.725598)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.725598)]}
# Episode finished after 996 timesteps
#
# [array(5.7477032)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.7477032)]}
# Episode finished after 997 timesteps
#
# [array(5.76794344)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.76794344)]}
# Episode finished after 998 timesteps
#
# [array(5.7878899)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.7878899)]}
# Episode finished after 999 timesteps
#
# [array(5.81664964)]
# [ 34.5        -54.36214217   0.        ]
# -100
# True
# {'Corriente': -1.5757142656575471, 'Temperatura': 25.0, 'Irradiancia': 1000.0, 'Accion': [array(5.81664964)]}
# Episode finished after 1000 timesteps

# %%
# rewardlst

epireward = np.sum(rewardlst)
print(epireward)

plt.plot(rewardlst)
plt.xlabel("Time Step")
plt.ylabel("Reward")
plt.show()
# Out:
# -88653.61266208484

# %%
# voltagelst
plt.plot(voltagelst)
plt.xlabel("Time Step")
plt.ylabel("Voltage")
plt.show()

# %%
# powerlst
plt.plot(powerlst)
plt.xlabel("Time Step")
plt.ylabel("Power")
plt.show()
